# %%
# # Bond Portfolio Optimization Comparison
# Running timed solver benchmarks using `opt_solver.py`.

# %%
# install solver software to python notebook 
# !pip install pyomo
# !pip install highspy

# %%
# import necessary libraries and modules 
import mip_bond_optimizer as mip
import opt_utils as utils 

# automatically refresh modules 
# %load_ext autoreload
# %autoreload 2

# %%
# load in datasets 
bond_universe, cov_matrix, sectors, returns = utils.load_and_preprocess()

# %%
# Access the functions using the alias
results = mip.run_all_scenarios(bond_universe)
# Out:
# Running Bond Scenario: Portfolio 1 — ~$50M target value, medium time horizon
# Status: Optimal Solution Found
# Portfolio Expected Return ($): 2,528,876.85
# Solve Time: 0.07 seconds
#
# 2528876.85
# Running Bond Scenario: Portfolio 2 — ~$20M target value, short time horizon, risk-averse
# Status: Optimal Solution Found
# Portfolio Expected Return ($): 933,928.34
# Solve Time: 0.09 seconds
#
# 933928.3400000001
# Running Bond Scenario: Portfolio 3 — ~$100M target value, long time horizon, moderate/high risk
# Status: Optimal Solution Found
# Portfolio Expected Return ($): 4,915,786.60
# Solve Time: 0.08 seconds
#
# 4915786.600000001

# %%
print(results)
# Out:
# {1: {'model': <pyomo.core.base.PyomoModel.ConcreteModel object at 0x1609eb3e0>, 'objective': 2528876.85, 'status': 'Optimal'}, 2: {'model': <pyomo.core.base.PyomoModel.ConcreteModel object at 0x160b2b480>, 'objective': 933928.3400000001, 'status': 'Optimal'}, 3: {'model': <pyomo.core.base.PyomoModel.ConcreteModel object at 0x160b2b070>, 'objective': 4915786.600000001, 'status': 'Optimal'}}
